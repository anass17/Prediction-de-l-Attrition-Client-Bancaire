# %% [markdown]
# ## Configuration et Initialisation de Spark
# ### Créer une session Spark optimisée pour le traitement distribué de DataFrames.

# %%
import os
from pyspark.sql import SparkSession

spark = (
    SparkSession.builder
    .appName("Prédiction de l'Attrition Client Bancaire")
    .getOrCreate()
)

print("Spark session started!")
# Out:
# Spark session started!

# %% [markdown]
# ### Vérifier la version de Spark.

# %%
print(spark.version)
# Out:
# 4.0.1
